# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Original image

# %%
img = cv2.imread("MyPhoto.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)
plt.title("Original Image")
plt.show()

# %% [markdown]
# # Histogram

# %%
hist, bins = np.histogram(img.flatten(), 256, [0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(), 256, [0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.title("Image Histogram")
plt.show()

# %% [markdown]
# # Equalized histogram

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
img_equ = cv2.equalizeHist(gray_img)

# %%
hist,bins = np.histogram(img_equ.flatten(), 256, [0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img_equ.flatten(), 256, [0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.title("Equalized Histogram")
plt.show()

# %% [markdown]
# # Image with equalized histogram

# %%
res = np.hstack((gray_img, img_equ))

# %%
plt.imshow(res)
plt.title("Grayscale image VS Equalized histogram grayscale image")
plt.show()
